# %% [markdown]
# **Google Drive Mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Load packages**

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %% [markdown]
# Now, We need to prepare our data to feed into the model. There is a builtin method in [Keras](https://keras.io/preprocessing/image/) that can extract your images from folders.
#
# Following is the gernalized function used to extract data from the directory.

# %%
def get_images(directory):
    Images = []
    Labels = []  
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'Normal': 
            label = 0
        elif labels == 'COVID-19':
            label = 1 
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {0:'Normal', 1:'COVID-19'}
    return labels[class_code]

# %%
Images, Labels = get_images('/content/drive/MyDrive/509/Radiology_workshop_monjoy/classification_raw_data/train_data/') #Extract the training images from the folders.

Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %%
Labels
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
Images.shape
# Out:
# (1684, 150, 150, 3)

# %% [markdown]
# Lets find shape of our traing data.
#
# As you see, The Training data is in shape of (Number of Training Images, Width of image, Height of image, Channel of image). This shape is very important. If you didnot resize the images to same size. It should be (No. of images,) shape. So, using this shape you cant feed the images to the model.

# %%
print("Shape of Images:",Images.shape)
print("Shape of Labels:",Labels.shape)
# Out:
# Shape of Images: (1684, 150, 150, 3)
# Shape of Labels: (1684,)

# %% [markdown]
# Let us look some random images of our dataset.

# %%
f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %% [markdown]
# Now, Create the CNN model to predict the class labels.This is the basic CNN model.

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(1,activation='sigmoid'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
#SVG(model_to_dot(model).create(prog='dot', format='svg'))
Utils.plot_model(model,to_file='model.png',show_shapes=True)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 148, 148, 200)     5600
#
#  conv2d_8 (Conv2D)           (None, 146, 146, 180)     324180
#
#  conv2d_9 (Conv2D)           (None, 144, 144, 180)     291780
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 180)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 26, 26, 180)       291780
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 140)       226940
#
#  conv2d_12 (Conv2D)          (None, 22, 22, 100)       126100
#
#  conv2d_13 (Conv2D)          (None, 20, 20, 50)        45050
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_4 (Dense)             (None, 180)               144180
#
#  dense_5 (Dense)             (None, 100)               18100
#
#  dense_6 (Dense)             (None, 50)                5050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1,478,811
# Trainable params: 1,478,811
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, lets train the model with validation split equal to 30% from training data. Validation split is used to determine that our model is not geting over-fitted.

# %%
import tensorflow as tf
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "./output/cp_NEW-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights every 1 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq=10)

# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path.format(epoch=0))

# Train the model with the new callback
trained = model.fit(Images,Labels,epochs=10,callbacks=[cp_callback],validation_split=0.30, verbose=1) #verbose meaning using or expressed in more words than are needed.
# Out:
# Epoch 1/10
#  9/37 [======>.......................] - ETA: 10s - loss: 1.7287 - accuracy: 0.5278
# Epoch 1: saving model to ./output/cp_NEW-0001.ckpt
# 19/37 [==============>...............] - ETA: 7s - loss: 1.2039 - accuracy: 0.5230
# Epoch 1: saving model to ./output/cp_NEW-0001.ckpt
# 29/37 [======================>.......] - ETA: 3s - loss: 1.0299 - accuracy: 0.5280
# Epoch 1: saving model to ./output/cp_NEW-0001.ckpt
# 37/37 [==============================] - 41s 601ms/step - loss: 0.9593 - accuracy: 0.5144 - val_loss: 0.6912 - val_accuracy: 0.5356
# Epoch 2/10
#  2/37 [>.............................] - ETA: 13s - loss: 0.6927 - accuracy: 0.5312
# Epoch 2: saving model to ./output/cp_NEW-0002.ckpt
# 12/37 [========>.....................] - ETA: 10s - loss: 0.6920 - accuracy: 0.5365
# Epoch 2: saving model to ./output/cp_NEW-0002.ckpt
# 22/37 [================>.............] - ETA: 6s - loss: 0.6908 - accuracy: 0.5455
# Epoch 2: saving model to ./output/cp_NEW-0002.ckpt
# 32/37 [========================>.....] - ETA: 2s - loss: 0.6917 - accuracy: 0.5439
# Epoch 2: saving model to ./output/cp_NEW-0002.ckpt
# 37/37 [==============================] - 18s 476ms/step - loss: 0.6916 - accuracy: 0.5433 - val_loss: 0.6911 - val_accuracy: 0.5356
# Epoch 3/10
#  5/37 [===>..........................] - ETA: 12s - loss: 0.6896 - accuracy: 0.5437
# Epoch 3: saving model to ./output/cp_NEW-0003.ckpt
# 15/37 [===========>..................] - ETA: 8s - loss: 0.6911 - accuracy: 0.5396
# Epoch 3: saving model to ./output/cp_NEW-0003.ckpt
# 25/37 [===================>..........] - ETA: 4s - loss: 0.6902 - accuracy: 0.5387
# Epoch 3: saving model to ./output/cp_NEW-0003.ckpt
# 35/37 [===========================>..] - ETA: 0s - loss: 0.6908 - accuracy: 0.5321
# Epoch 3: saving model to ./output/cp_NEW-0003.ckpt
# 37/37 [==============================] - 18s 486ms/step - loss: 0.6910 - accuracy: 0.5306 - val_loss: 0.6889 - val_accuracy: 0.5356
# Epoch 4/10
#  8/37 [=====>........................] - ETA: 11s - loss: 0.6870 - accuracy: 0.5586
# Epoch 4: saving model to ./output/cp_NEW-0004.ckpt
# 18/37 [=============>................] - ETA: 7s - loss: 0.6872 - accuracy: 0.5365
# Epoch 4: saving model to ./output/cp_NEW-0004.ckpt
# 28/37 [=====================>........] - ETA: 3s - loss: 0.6859 - accuracy: 0.5491
# Epoch 4: saving model to ./output/cp_NEW-0004.ckpt
# 37/37 [==============================] - 17s 457ms/step - loss: 0.6877 - accuracy: 0.5441 - val_loss: 0.6899 - val_accuracy: 0.5356
# Epoch 5/10
#  1/37 [..............................] - ETA: 14s - loss: 0.7115 - accuracy: 0.4062
# Epoch 5: saving model to ./output/cp_NEW-0005.ckpt
# 11/37 [=======>......................] - ETA: 10s - loss: 0.6961 - accuracy: 0.4858
# Epoch 5: saving model to ./output/cp_NEW-0005.ckpt
# 21/37 [================>.............] - ETA: 6s - loss: 0.6928 - accuracy: 0.5164
# Epoch 5: saving model to ./output/cp_NEW-0005.ckpt
# 31/37 [========================>.....] - ETA: 2s - loss: 0.6922 - accuracy: 0.5333
# Epoch 5: saving model to ./output/cp_NEW-0005.ckpt
# 37/37 [==============================] - 17s 452ms/step - loss: 0.6918 - accuracy: 0.5365 - val_loss: 0.6903 - val_accuracy: 0.5356
# Epoch 6/10
#  4/37 [==>...........................] - ETA: 12s - loss: 0.6941 - accuracy: 0.4844
# Epoch 6: saving model to ./output/cp_NEW-0006.ckpt
# 14/37 [==========>...................] - ETA: 9s - loss: 0.6891 - accuracy: 0.5446
# Epoch 6: saving model to ./output/cp_NEW-0006.ckpt
# 24/37 [==================>...........] - ETA: 5s - loss: 0.6906 - accuracy: 0.5404
# Epoch 6: saving model to ./output/cp_NEW-0006.ckpt
# 34/37 [==========================>...] - ETA: 1s - loss: 0.6911 - accuracy: 0.5432
# Epoch 6: saving model to ./output/cp_NEW-0006.ckpt
# 37/37 [==============================] - 17s 452ms/step - loss: 0.6904 - accuracy: 0.5424 - val_loss: 0.6901 - val_accuracy: 0.5356
# Epoch 7/10
#  7/37 [====>.........................] - ETA: 11s - loss: 0.6925 - accuracy: 0.5179
# Epoch 7: saving model to ./output/cp_NEW-0007.ckpt
# 17/37 [============>.................] - ETA: 7s - loss: 0.6924 - accuracy: 0.5312
# Epoch 7: saving model to ./output/cp_NEW-0007.ckpt
# 27/37 [====================>.........] - ETA: 3s - loss: 0.6911 - accuracy: 0.5394
# Epoch 7: saving model to ./output/cp_NEW-0007.ckpt
# 37/37 [==============================] - 17s 448ms/step - loss: 0.6908 - accuracy: 0.5374 - val_loss: 0.6887 - val_accuracy: 0.5356
# Epoch 8/10
#
# Epoch 8: saving model to ./output/cp_NEW-0008.ckpt
# 10/37 [=======>......................] - ETA: 10s - loss: 0.6962 - accuracy: 0.5063
# Epoch 8: saving model to ./output/cp_NEW-0008.ckpt
# 20/37 [===============>..............] - ETA: 6s - loss: 0.6916 - accuracy: 0.5203
# Epoch 8: saving model to ./output/cp_NEW-0008.ckpt
# 30/37 [=======================>......] - ETA: 2s - loss: 0.6836 - accuracy: 0.5427
# Epoch 8: saving model to ./output/cp_NEW-0008.ckpt
# 37/37 [==============================] - 17s 454ms/step - loss: 0.6859 - accuracy: 0.5424 - val_loss: 0.6883 - val_accuracy: 0.5356
# Epoch 9/10
#  3/37 [=>............................] - ETA: 13s - loss: 0.6846 - accuracy: 0.5521
# Epoch 9: saving model to ./output/cp_NEW-0009.ckpt
# 13/37 [=========>....................] - ETA: 9s - loss: 0.6824 - accuracy: 0.5505
# Epoch 9: saving model to ./output/cp_NEW-0009.ckpt
# 23/37 [=================>............] - ETA: 5s - loss: 0.6897 - accuracy: 0.5408
# Epoch 9: saving model to ./output/cp_NEW-0009.ckpt
# 33/37 [=========================>....] - ETA: 1s - loss: 0.6911 - accuracy: 0.5237
# Epoch 9: saving model to ./output/cp_NEW-0009.ckpt
# 37/37 [==============================] - 18s 480ms/step - loss: 0.6909 - accuracy: 0.5246 - val_loss: 0.6933 - val_accuracy: 0.5356
# Epoch 10/10
#  6/37 [===>..........................] - ETA: 12s - loss: 0.7017 - accuracy: 0.4792
# Epoch 10: saving model to ./output/cp_NEW-0010.ckpt
# 16/37 [===========>..................] - ETA: 8s - loss: 0.6958 - accuracy: 0.5117
# Epoch 10: saving model to ./output/cp_NEW-0010.ckpt
# 26/37 [====================>.........] - ETA: 4s - loss: 0.6950 - accuracy: 0.5276
# Epoch 10: saving model to ./output/cp_NEW-0010.ckpt
# 36/37 [============================>.] - ETA: 0s - loss: 0.6933 - accuracy: 0.5365
# Epoch 10: saving model to ./output/cp_NEW-0010.ckpt
# 37/37 [==============================] - 18s 478ms/step - loss: 0.6935 - accuracy: 0.5331 - val_loss: 0.6899 - val_accuracy: 0.5356

# %%
# !ls {checkpoint_dir}
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# checkpoint			      cp_NEW-0005.ckpt.index
# cp_NEW-0000.ckpt.data-00000-of-00001  cp_NEW-0006.ckpt.data-00000-of-00001
# cp_NEW-0000.ckpt.index		      cp_NEW-0006.ckpt.index
# cp_NEW-0001.ckpt.data-00000-of-00001  cp_NEW-0007.ckpt.data-00000-of-00001
# cp_NEW-0001.ckpt.index		      cp_NEW-0007.ckpt.index
# cp_NEW-0002.ckpt.data-00000-of-00001  cp_NEW-0008.ckpt.data-00000-of-00001
# cp_NEW-0002.ckpt.index		      cp_NEW-0008.ckpt.index
# cp_NEW-0003.ckpt.data-00000-of-00001  cp_NEW-0009.ckpt.data-00000-of-00001
# cp_NEW-0003.ckpt.index		      cp_NEW-0009.ckpt.index
# cp_NEW-0004.ckpt.data-00000-of-00001  cp_NEW-0010.ckpt.data-00000-of-00001
# cp_NEW-0004.ckpt.index		      cp_NEW-0010.ckpt.index
# cp_NEW-0005.ckpt.data-00000-of-00001
# './output/cp_NEW-0010.ckpt'

# %% [markdown]
# **Load a Trained Model**

# %%
chk_path= './output/cp_NEW-0080.ckpt'
# Load the previously saved weights
model.load_weights(chk_path)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-11-f5394b5867ca> in <module>
#       1 chk_path= './output/cp_NEW-0080.ckpt'
#       2 # Load the previously saved weights
# ----> 3 model.load_weights(chk_path)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/py_checkpoint_reader.py in error_translator(e)
#      29       'Failed to find any '
#      30       'matching files for') in error_message:
# ---> 31     raise errors_impl.NotFoundError(None, None, error_message)
#      32   elif 'Sliced checkpoints are not supported' in error_message or (
#      33       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ./output/cp_NEW-0080.ckpt

# %% [markdown]
# **Plot Training and Testing Graphs**

# %%
plot.plot(trained.history['accuracy'])
plot.plot(trained.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %% [markdown]
# To evaluate a model, there are many methods are proposed to evaluate the model. I use Accuracy to evaluate the performance of my model.

# %%
test_images,test_labels = get_images('/content/drive/MyDrive/509/Radiology_workshop_monjoy/classification_raw_data/test_data/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6978 - accuracy: 0.4286
# [0.6977691650390625, 0.4285714328289032]

# %% [markdown]
# Lets predict the images from the "pred" folder.

# %%
y_pred = model.predict(test_images)
y_pred= y_pred.round()
#y_pred

# %%
len(test_labels)
# Out:
# 21

# %% [markdown]
# **Generate a classification report**

# %%
from sklearn.metrics import classification_report
report = classification_report(test_labels, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %% [markdown]
# **Plot Prediction Results**

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(21):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(test_images))
    pred_image = np.array([test_images[i]])
    pred_prob = model.predict(pred_image)[0]
    #print(pred_prob)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            if pred_prob <0.5:
               ax.set_title('Normal')
            else:
               ax.set_title('COVID-19')
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
fig.show()
